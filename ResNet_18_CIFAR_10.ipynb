# %% [markdown]
# <a href="https://colab.research.google.com/github/unasthana/ResNet18_CIFAR_10/blob/main/ResNet_18_CIFAR_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Training ResNet18 on CIFAR - 10 Dataset**
# **-- Ujjwal Asthana, Shivani Singh, Shruti Wagle**
#
# The challenge is to train a ResNet model on the CIFAR - 10 dataset such that the number of trainable paramters do not exceed 5 Million.

# %% [markdown]
# ## Part - 1: Notebook Imports and Intializations

# %%
# Necessary Imports

import os
import random
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import matplotlib.pyplot as plt

from torchsummary import summary
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %% [markdown]
# Firstly, we will be defining some constants. Batch size is taken as 128 for both the training and testing set. We will be training the network for 100 epochs on the available GPU system.

# %%
# Global Constants

SEED = 42
BATCH_SIZE = 128
EPOCHS = 100
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
PATH = "/content/models"

# %% [markdown]
# Secondly, in order to make our results reproducible for multiple re-runs, we will be setting seeds for different non-deterministic systems.

# %%
# Setting both CPU and GPU seeds for reproducibility

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)


torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Part - 2: Data Preprocessing

# %% [markdown]
# Now, we will download the CIFAR - 10 dataset and apply the following data augmentations:
#
#
# *   **Cropping:** This tranformation crops the image at a random location. For eg: transforms.RandomCrop(32, padding = 4) crops a square patch of size 32x32 from an input image with a padding of 4 pixels on all sides. The padding is added to the input image before the random cropping to avoid cropping important parts of the image. This transformation adds diversity to the dataset by adding variations in the position and scale of objects in the image. By randomly cropping different parts of the image, the model learns to recognize objects from different perspectives and positions, leading to better generalization performance.
#
# *   **Horizontal Flip:** This transformation horizontally flips an image randomly with a probability of 0.5 (i.e., with a 50% chance). It is important to note that by randomly flipping images horizontally, the model learns to recognize objects regardless of their orientation in the image, leading to better generalization performance.
#
# *   **Rotation:** This transformation randomly rotates an image by a maximum angle which is assigned as a paramter either in clockwise or counterclockwise direction. For eg: transforms.RandomRotation(10) randomly rotates the image by a random angle in the range [-10, 10] degrees. It is important to note that by randomly rotating images, the model learns to recognize objects from different orientations and angles, leading to better generalization performance.
#
# *   **Normalization:** This transformation normalizes the pixel values of an image. In particular, it subtracts from each pixel value, the mean of each color channel and divides it by its standard deviation. The parameters (0.4914, 0.4822, 0.4465) and (0.2023, 0.1994, 0.2010) are the mean and standard deviation of the three color channels (red, green, and blue) for the CIFAR-10 dataset to which this transformation is applied to. This transformation helps to make the training process more stable and efficient by reducing the impact of differences in lighting conditions and color distributions between images. By normalizing the pixel values of an image, the range of values is typically constrained to a smaller range, typically between -1 and 1, which can make the optimization process easier and can improve the model's accuracy.

# %%
# Downloading dataset and performing data augmentations

transform_train = transforms.Compose([transforms.RandomCrop(32, padding = 4), 
                                      transforms.RandomHorizontalFlip(), 
                                      transforms.RandomRotation(10), 
                                      transforms.ToTensor(), 
                                transforms.Normalize((0.4914, 0.4822, 0.4465), 
                                                  (0.2023, 0.1994, 0.2010)),])

transform_test = transforms.Compose([transforms.ToTensor(), 
                                transforms.Normalize((0.4914, 0.4822, 0.4465), 
                                                  (0.2023, 0.1994, 0.2010)),])

trainset = torchvision.datasets.CIFAR10(root = './data', train = True, 
                                        download = True, 
                                        transform = transform_train)

trainloader = torch.utils.data.DataLoader(trainset, batch_size = BATCH_SIZE, 
                                          shuffle = True, num_workers = 2)

testset = torchvision.datasets.CIFAR10(root = './data', train = False, 
                                       download = True, 
                                       transform = transform_test)

testloader = torch.utils.data.DataLoader(testset, batch_size = BATCH_SIZE, 
                                         shuffle = False, num_workers = 2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 13113546.23it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ##Part - 3: ResNet18 Design

# %% [markdown]
# Finally, let us now start designing the Residual Block for our ResNet18 network.
#
# A Residual Block is a structure which is designed to help with the problem of vanishing gradients, which can occur when the gradients become too small to be useful for learning. This problem is particularly pronounced in deep networks that has many layers.
#
# The Residual Block works by adding a "shortcut connection" around one or more layers in the block. The shortcut connection adds the input to the output of the block, so that the final output is the sum of the input and the output of the block. This allows the gradient to flow through the shortcut connection, bypassing some of the layers in the block and helping to mitigate the vanishing gradient problem.
#
# The Residual Block for our ResNet model takes as input the number of input channels, the number of output channels, and a boolean value indicating whether the block should downsample the input (i.e., reduce the spatial resolution of the input) or not.
#
# If the block is downsampling, it uses a convolutional layer with a stride of 2 to reduce the spatial resolution of the input. It also uses a "shortcut" convolutional layer with a stride of 2 to match the spatial resolution of the input and the output channels.
#
# If the block is not downsampling, it uses a convolutional layer with a stride of 1 to preserve the spatial resolution of the input. It does not use a shortcut convolutional layer.
#
# Both versions of the block then apply batch normalization and ReLU activation functions to the output of the convolutional layers, and then add the shortcut connection to the output. The final output of the block is the ReLU activation of the sum of the input and output.

# %%
# Designing Residual Block for the ResNet18

class ResBlock(nn.Module):

    def __init__(self, in_channels, out_channels, downsample):

        super().__init__()
        
        if downsample:
            self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size = 3,
                                   stride = 2, padding = 1)
            
            self.shortcut = nn.Sequential(nn.Conv2d(in_channels, out_channels,
                                                    kernel_size = 1, 
                                                    stride = 2), 
                                          nn.BatchNorm2d(out_channels))
        
        else:
            self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size = 3,
                                   stride = 1, padding = 1)
            
            self.shortcut = nn.Sequential()

        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size = 3,
                               stride = 1, padding = 1)
        
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

    
    def forward(self, input):

        shortcut = self.shortcut(input)
        input = self.conv1(input)
        input = self.bn1(input)
        input = nn.ReLU()(input)
        input = self.conv2(input)
        input = self.bn2(input)

        input = input + shortcut
        output = nn.ReLU()(input)

        return output

# %% [markdown]
# Now, let us design the ResNet18 architecture.
#
# This network takes in three arguments: 'in_channels' which represents the number of input channels, 'resblock' which is the ResBlock class defined earlier, and outputs which represents the number of output classes (10 for CIFAR - 10).
#
# The ResNet18 architecture begins with a 'layer0' which is a sequence of convolutional, batch normalization, and ReLU layers. 'layer0' takes the input image and applies a convolutional operation with a kernel size of 3, followed by batch normalization and ReLU activation. This operation is designed to extract low-level features from the input image.
#
# The architecture then continues with a series of four ResBlock layers ('layer1' through 'layer4'). Each ResBlock layer consists of multiple ResBlocks stacked together, and each ResBlock layer has a different number of output channels and downsampling settings. The downsample argument in the ResBlock class determines whether or not the shortcut connection should perform downsampling or not.
#
# After the four ResBlock layers, the architecture applies an average pooling operation with a kernel size of 4, followed by flattening the output and passing it through a fully connected layer with outputs number of units. The output of this fully connected layer represents the final classification result.
#
# In conclusion, it is designed to enable the training of very deep neural networks by introducing skip connections between the layers, which allow for the training of much deeper networks than was previously possible.

# %%
# Designing ResNet18 from Residual Blocks

class ResNet18(nn.Module):

    def __init__(self, in_channels, resblock, outputs = 10):

        super().__init__()
        
        self.layer0 = nn.Sequential(nn.Conv2d(3, 42, kernel_size = 3, 
                                              stride = 1, padding = 1), 
                                    nn.BatchNorm2d(42), nn.ReLU())

        self.layer1 = nn.Sequential(
            resblock(42, 42, downsample = False),
            resblock(42, 42, downsample = False)
        )

        self.layer2 = nn.Sequential(
            resblock(42, 84, downsample = True),
            resblock(84, 84, downsample = False)
        )

        self.layer3 = nn.Sequential(
            resblock(84, 168, downsample = True),
            resblock(168, 168, downsample = False)
        )

        self.layer4 = nn.Sequential(
            resblock(168, 336, downsample = True),
            resblock(336, 336, downsample = False)
        )

        self.fc = torch.nn.Linear(336, outputs)

    def forward(self, input):
        
        input = self.layer0(input)
        input = self.layer1(input)
        input = self.layer2(input)
        input = self.layer3(input)
        input = self.layer4(input)

        input = F.avg_pool2d(input, 4)
        input = input.view(input.size(0), -1)
        output = self.fc(input)

        return output

# %% [markdown]
# Now, let us define a function to initialize the network according to our needs. We will be using cross-entropy loss here.
#
# Cross-entropy loss is a good choice here as it has a very desirable property of being able to penalize incorrect confident predictions. In other words, if the model is very confident about a wrong prediction, the cross-entropy loss will be high and the model will be penalized more heavily for that error. This property is especially important for multi-class classification tasks, where the model has to choose between several different classes, as it encourages the model to produce a more accurate probability distribution over the classes.

# %%
# Defining function to initialize the neural network

def initNetwork():

    global criterion

    criterion = nn.CrossEntropyLoss()
    net = ResNet18(3, ResBlock, outputs = 10)
    net.to(DEVICE) 

    return net

# %% [markdown]
# Next, we define the function that trains our ResNet.

# %%
# Defining the train function

train_accs = []
train_losses = [] 


def train(epoch):

    print('\nEpoch: %d' % (epoch + 1))
    net.train()

    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(trainloader):

        inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
        optimizer.zero_grad()
        outputs = net(inputs)

        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    train_acc = correct * 100 / total
    train_loss = train_loss / len(trainloader)

    train_accs.append(train_acc)
    train_losses.append(train_loss)

    print("Train Loss = " + str(train_loss) + "\t \t" + "Train Accuracy = " +
          str(correct) + "/" + str(total) + " = " + str(train_acc))

# %% [markdown]
# Next, we define the function that tests our ResNet every epoch on the test dataset.

# %%
# Defining the test function

test_accs = []
test_losses = []

def test(epoch):

    net.eval()
    test_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):

            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)

            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    acc = 100. * correct / total
    test_loss = test_loss / len(testloader)

    test_accs.append(acc)
    test_losses.append(test_loss)

    print("Test Loss = " + str(test_loss) + "\t \t" + "Test accuracy = " + 
          str(correct) + "/" + str(total)+" = " + str(acc))
    
    return acc

# %% [markdown]
# Next, we define the function that plots the training/testing accuracies as well as the training/testing losses over the course of the entire training process.

# %%
# Plotting Losses and Accuracies

def plot_metrics(train_accs, test_accs, train_losses, test_losses, epoch, 
                 value):

    f, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 6))

    ax1.plot(range(EPOCHS), train_losses, '-', linewidth = '3', 
             label = 'Train Error')
    
    ax1.plot(range(EPOCHS), test_losses, '-', linewidth = '3', 
             label = 'Test Error')
    
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.set_title("Loss Vs Epoch")

    ax2.plot(range(EPOCHS), train_accs, '-', linewidth = '3', 
             label = 'Train Accuracy')
    
    ax2.plot(range(EPOCHS), test_accs, '-', linewidth = '3', 
             label = 'Test Acuracy')
    
    ax2.annotate("Max Accuracy = " + str(value), xy = (epoch, value), 
                 xytext = (epoch + 5, value + 5), 
                 arrowprops  = dict(facecolor = 'black', shrink = 0.05))
    
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Loss")
    ax2.set_title("Accuracy Vs Epoch")

    ax1.grid(True)
    ax2.grid(True)
    ax1.legend()
    ax2.legend()

# %% [markdown]
# Now, let us check whether our model is in budget or not.

# %%
# Defining model and printing summary

net = ResNet18(3, ResBlock, outputs = 10)
net.to(DEVICE)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 42, 32, 32]           1,176
#        BatchNorm2d-2           [-1, 42, 32, 32]              84
#               ReLU-3           [-1, 42, 32, 32]               0
#             Conv2d-4           [-1, 42, 32, 32]          15,918
#        BatchNorm2d-5           [-1, 42, 32, 32]              84
#             Conv2d-6           [-1, 42, 32, 32]          15,918
#        BatchNorm2d-7           [-1, 42, 32, 32]              84
#           ResBlock-8           [-1, 42, 32, 32]               0
#             Conv2d-9           [-1, 42, 32, 32]          15,918
#       BatchNorm2d-10           [-1, 42, 32, 32]              84
#            Conv2d-11           [-1, 42, 32, 32]          15,918
#       BatchNorm2d-12           [-1, 42, 32, 32]              84
#          ResBlock-13           [-1, 42, 32, 32]               0
#            Conv2d-14           [-1, 84, 16, 16]           3,612
#       BatchNorm2d-15           [-1, 84, 16, 16]             168
#            Conv2d-16           [-1, 84, 16, 16]          31,836
#       BatchNorm2d-17           [-1, 84, 16, 16]             168
#            Conv2d-18           [-1, 84, 16, 16]          63,588
#       BatchNorm2d-19           [-1, 84, 16, 16]             168
#          ResBlock-20           [-1, 84, 16, 16]               0
#            Conv2d-21           [-1, 84, 16, 16]          63,588
#       BatchNorm2d-22           [-1, 84, 16, 16]             168
#            Conv2d-23           [-1, 84, 16, 16]          63,588
#       BatchNorm2d-24           [-1, 84, 16, 16]             168
#          ResBlock-25           [-1, 84, 16, 16]               0
#            Conv2d-26            [-1, 168, 8, 8]          14,280
#       BatchNorm2d-27            [-1, 168, 8, 8]             336
#            Conv2d-28            [-1, 168, 8, 8]         127,176
#       BatchNorm2d-29            [-1, 168, 8, 8]             336
#            Conv2d-30            [-1, 168, 8, 8]         254,184
#       BatchNorm2d-31            [-1, 168, 8, 8]             336
#          ResBlock-32            [-1, 168, 8, 8]               0
#            Conv2d-33            [-1, 168, 8, 8]         254,184
#       BatchNorm2d-34            [-1, 168, 8, 8]             336
#            Conv2d-35            [-1, 168, 8, 8]         254,184
#       BatchNorm2d-36            [-1, 168, 8, 8]             336
#          ResBlock-37            [-1, 168, 8, 8]               0
#            Conv2d-38            [-1, 336, 4, 4]          56,784
#       BatchNorm2d-39            [-1, 336, 4, 4]             672
#            Conv2d-40            [-1, 336, 4, 4]         508,368
#       BatchNorm2d-41            [-1, 336, 4, 4]             672
#            Conv2d-42            [-1, 336, 4, 4]       1,016,400
#       BatchNorm2d-43            [-1, 336, 4, 4]             672
#          ResBlock-44            [-1, 336, 4, 4]               0
#            Conv2d-45            [-1, 336, 4, 4]       1,016,400
#       BatchNorm2d-46            [-1, 336, 4, 4]             672
#            Conv2d-47            [-1, 336, 4, 4]       1,016,400
#       BatchNorm2d-48            [-1, 336, 4, 4]             672
#          ResBlock-49            [-1, 336, 4, 4]               0
#            Linear-50                   [-1, 10]           3,370
# ================================================================
# Total params: 4,819,090
# Trainable params: 4,819,090
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 7.71
# Params size (MB): 18.38
# Estimated Total Size (MB): 26.11
# ----------------------------------------------------------------

# %% [markdown]
# We can see from the above output that the number of trainable parameters is around 4.8 Million. Therefore, the model is in budget and we can proceed forward with the training process.

# %% [markdown]
# Now, we initialize the ResNet18, select an appropriate optimizer and implement some learning rate decay scheme for our training process.
#
# We use the stochastic gradient descent (SGD) algorithm with some momentum as our optimizer here. The learning rate determines the step size at each iteration of the optimization process. The momentum determines the contribution of the previous update to the current update, helping to accelerate the convergence of the optimization process. Finally, the weight_decay parameter applies L2 regularization to the weights, preventing overfitting and improving the generalization ability of the model.
#
# For our learning rate scheduler, we choose the 'CosineAnnealingLR' function, which gradually reduces the learning rate over the course of training. This is how the learning rate is decided in CosineAnnealingLR:
#
# ![piv3.png](data:image/png;base64,...)
#
# 'T_max' : the number of epochs for which the learning rate will be reduced.
#
# 'T_cur' : the current epoch
#
# 'eta_max' : Maximum Learning Rate
#
# 'eta_min' : Minimum Learning Rate
#
# 'eta_t' : The learning rate at 'T_cur' (the current learning rate)
#
# By using a learning rate scheduler, the optimization process becomes more stable and efficient, as the learning rate is decreased over time, allowing the model to converge more smoothly.

# %% [markdown]
# ## Part - 4: Training ResNet18

# %% [markdown]
# In our notebook, we stick with a momentum of 0.0005 and a weight_decay of 5e-4 and experiment with 4 different learning rates.

# %% [markdown]
# First, let us create a directory for storing model weights.

# %%
try: 
    os.mkdir(PATH)
     
except OSError as error: 
    print(error)

# %% [markdown]
# ### CASE - 1: lr = 0.125, momentum = 0.0005, weight_decay = 5e-4

# %%
# Initializing network and setting optimizer and Learning Rate Decay (CASE - 1)

net = initNetwork()

optimizer = optim.SGD(net.parameters(), lr = 0.125, momentum = 0.0005, 
                      weight_decay = 5e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 
                                                       T_max = EPOCHS)

# %%
# Training the ResNet18 (CASE - 1)

best_acc = 0

train_accs = []
train_losses = []

test_accs = []
test_losses = []

for epoch in range(EPOCHS):
  
  train(epoch)
  acc = test(epoch)

  if acc > best_acc:
      best_acc = acc
      torch.save(net.state_dict(), '/content/models/resnet1.pt')
  
  print("Best Test Accuracy = " + str(best_acc))
  scheduler.step()
# Out:
# Epoch: 1
# Train Loss = 1.6913665502577486	 	Train Accuracy = 19133/50000 = 38.266
# Test Loss = 1.9617153557041023	 	Test accuracy = 4050/10000 = 40.5
# Best Test Accuracy = 40.5
#
# Epoch: 2
# Train Loss = 1.1691267016293752	 	Train Accuracy = 28838/50000 = 57.676
# Test Loss = 1.1069343150416506	 	Test accuracy = 6092/10000 = 60.92
# Best Test Accuracy = 60.92
#
# Epoch: 3
# Train Loss = 0.9099688726617857	 	Train Accuracy = 33744/50000 = 67.488
# Test Loss = 1.66919173771822	 	Test accuracy = 5416/10000 = 54.16
# Best Test Accuracy = 60.92
#
# Epoch: 4
# Train Loss = 0.761976348926954	 	Train Accuracy = 36548/50000 = 73.096
# Test Loss = 0.7485799932781654	 	Test accuracy = 7508/10000 = 75.08
# Best Test Accuracy = 75.08
#
# Epoch: 5
# Train Loss = 0.6656961795466635	 	Train Accuracy = 38342/50000 = 76.684
# Test Loss = 1.3951338295695148	 	Test accuracy = 6221/10000 = 62.21
# Best Test Accuracy = 75.08
#
# Epoch: 6
# Train Loss = 0.6013972538968791	 	Train Accuracy = 39481/50000 = 78.962
# Test Loss = 0.7023229191574869	 	Test accuracy = 7626/10000 = 76.26
# Best Test Accuracy = 76.26
#
# Epoch: 7
# Train Loss = 0.5539087565506206	 	Train Accuracy = 40315/50000 = 80.63
# Test Loss = 0.6259191160715079	 	Test accuracy = 7909/10000 = 79.09
# Best Test Accuracy = 79.09
#
# Epoch: 8
# Train Loss = 0.5124917025761226	 	Train Accuracy = 41071/50000 = 82.142
# Test Loss = 0.6524733052223544	 	Test accuracy = 7901/10000 = 79.01
# Best Test Accuracy = 79.09
#
# Epoch: 9
# Train Loss = 0.4813627935279056	 	Train Accuracy = 41638/50000 = 83.276
# Test Loss = 0.5771095213256304	 	Test accuracy = 8124/10000 = 81.24
# Best Test Accuracy = 81.24
#
# Epoch: 10
# Train Loss = 0.4498077032282529	 	Train Accuracy = 42191/50000 = 84.382
# Test Loss = 0.6265292220477816	 	Test accuracy = 7961/10000 = 79.61
# Best Test Accuracy = 81.24
#
# Epoch: 11
# Train Loss = 0.42446179642244375	 	Train Accuracy = 42572/50000 = 85.144
# Test Loss = 0.47193719390072403	 	Test accuracy = 8399/10000 = 83.99
# Best Test Accuracy = 83.99
#
# Epoch: 12
# Train Loss = 0.40274229912501774	 	Train Accuracy = 43005/50000 = 86.01
# Test Loss = 0.5334182868275461	 	Test accuracy = 8238/10000 = 82.38
# Best Test Accuracy = 83.99
#
# Epoch: 13
# Train Loss = 0.38851603979954635	 	Train Accuracy = 43163/50000 = 86.326
# Test Loss = 0.49844764342790915	 	Test accuracy = 8364/10000 = 83.64
# Best Test Accuracy = 83.99
#
# Epoch: 14
# Train Loss = 0.36868493346606984	 	Train Accuracy = 43553/50000 = 87.106
# Test Loss = 0.5266557041602798	 	Test accuracy = 8302/10000 = 83.02
# Best Test Accuracy = 83.99
#
# Epoch: 15
# Train Loss = 0.3530877066771393	 	Train Accuracy = 43849/50000 = 87.698
# Test Loss = 0.46400732141506823	 	Test accuracy = 8498/10000 = 84.98
# Best Test Accuracy = 84.98
#
# Epoch: 16
# Train Loss = 0.33543910006123123	 	Train Accuracy = 44164/50000 = 88.328
# Test Loss = 0.4640421580664719	 	Test accuracy = 8471/10000 = 84.71
# Best Test Accuracy = 84.98
#
# Epoch: 17
# Train Loss = 0.32664817796491297	 	Train Accuracy = 44272/50000 = 88.544
# Test Loss = 0.3688853992314278	 	Test accuracy = 8731/10000 = 87.31
# Best Test Accuracy = 87.31
#
# Epoch: 18
# Train Loss = 0.3093980563342419	 	Train Accuracy = 44627/50000 = 89.254
# Test Loss = 0.4668344025370441	 	Test accuracy = 8486/10000 = 84.86
# Best Test Accuracy = 87.31
#
# Epoch: 19
# Train Loss = 0.2977096291682909	 	Train Accuracy = 44797/50000 = 89.594
# Test Loss = 0.44427806591685814	 	Test accuracy = 8550/10000 = 85.5
# Best Test Accuracy = 87.31
#
# Epoch: 20
# Train Loss = 0.28837692474617677	 	Train Accuracy = 45026/50000 = 90.052
# Test Loss = 0.4492360402511645	 	Test accuracy = 8566/10000 = 85.66
# Best Test Accuracy = 87.31
#
# Epoch: 21
# Train Loss = 0.27995805493782244	 	Train Accuracy = 45073/50000 = 90.146
# Test Loss = 0.39382964806466164	 	Test accuracy = 8707/10000 = 87.07
# Best Test Accuracy = 87.31
#
# Epoch: 22
# Train Loss = 0.2689927911666958	 	Train Accuracy = 45390/50000 = 90.78
# Test Loss = 0.4431147098164015	 	Test accuracy = 8572/10000 = 85.72
# Best Test Accuracy = 87.31
#
# Epoch: 23
# Train Loss = 0.2585696529244523	 	Train Accuracy = 45485/50000 = 90.97
# Test Loss = 0.3821526388578777	 	Test accuracy = 8793/10000 = 87.93
# Best Test Accuracy = 87.93
#
# Epoch: 24
# Train Loss = 0.2545203582557571	 	Train Accuracy = 45536/50000 = 91.072
# Test Loss = 0.375854823031003	 	Test accuracy = 8794/10000 = 87.94
# Best Test Accuracy = 87.94
#
# Epoch: 25
# Train Loss = 0.24273036972945913	 	Train Accuracy = 45646/50000 = 91.292
# Test Loss = 0.3918088178468656	 	Test accuracy = 8719/10000 = 87.19
# Best Test Accuracy = 87.94
#
# Epoch: 26
# Train Loss = 0.23809909525201145	 	Train Accuracy = 45857/50000 = 91.714
# Test Loss = 0.34766600479053544	 	Test accuracy = 8891/10000 = 88.91
# Best Test Accuracy = 88.91
#
# Epoch: 27
# Train Loss = 0.2298328110286037	 	Train Accuracy = 45897/50000 = 91.794
# Test Loss = 0.3753242519082902	 	Test accuracy = 8801/10000 = 88.01
# Best Test Accuracy = 88.91
#
# Epoch: 28
# Train Loss = 0.22067288713305808	 	Train Accuracy = 46126/50000 = 92.252
# Test Loss = 0.375025350270392	 	Test accuracy = 8800/10000 = 88.0
# Best Test Accuracy = 88.91
#
# Epoch: 29
# Train Loss = 0.2112975837781911	 	Train Accuracy = 46308/50000 = 92.616
# Test Loss = 0.3580067255828954	 	Test accuracy = 8851/10000 = 88.51
# Best Test Accuracy = 88.91
#
# Epoch: 30
# Train Loss = 0.20947048491071862	 	Train Accuracy = 46334/50000 = 92.668
# Test Loss = 0.42539109195335	 	Test accuracy = 8735/10000 = 87.35
# Best Test Accuracy = 88.91
#
# Epoch: 31
# Train Loss = 0.19779328655099015	 	Train Accuracy = 46469/50000 = 92.938
# Test Loss = 0.34882681015171585	 	Test accuracy = 8892/10000 = 88.92
# Best Test Accuracy = 88.92
#
# Epoch: 32
# Train Loss = 0.19281692010209994	 	Train Accuracy = 46631/50000 = 93.262
# Test Loss = 0.400332640243482	 	Test accuracy = 8743/10000 = 87.43
# Best Test Accuracy = 88.92
#
# Epoch: 33
# Train Loss = 0.18989314725789266	 	Train Accuracy = 46652/50000 = 93.304
# Test Loss = 0.41428397935402544	 	Test accuracy = 8713/10000 = 87.13
# Best Test Accuracy = 88.92
#
# Epoch: 34
# Train Loss = 0.1854715241628992	 	Train Accuracy = 46788/50000 = 93.576
# Test Loss = 0.3822664871246	 	Test accuracy = 8791/10000 = 87.91
# Best Test Accuracy = 88.92
#
# Epoch: 35
# Train Loss = 0.1723305282309232	 	Train Accuracy = 47021/50000 = 94.042
# Test Loss = 0.4009163624878171	 	Test accuracy = 8754/10000 = 87.54
# Best Test Accuracy = 88.92
#
# Epoch: 36
# Train Loss = 0.17125010414196706	 	Train Accuracy = 47024/50000 = 94.048
# Test Loss = 0.3618267270960385	 	Test accuracy = 8908/10000 = 89.08
# Best Test Accuracy = 89.08
#
# Epoch: 37
# Train Loss = 0.1608300561757039	 	Train Accuracy = 47176/50000 = 94.352
# Test Loss = 0.37276194404952134	 	Test accuracy = 8857/10000 = 88.57
# Best Test Accuracy = 89.08
#
# Epoch: 38
# Train Loss = 0.1599412696231204	 	Train Accuracy = 47183/50000 = 94.366
# Test Loss = 0.43979134146548526	 	Test accuracy = 8700/10000 = 87.0
# Best Test Accuracy = 89.08
#
# Epoch: 39
# Train Loss = 0.15432733909019727	 	Train Accuracy = 47250/50000 = 94.5
# Test Loss = 0.36309083334252806	 	Test accuracy = 8883/10000 = 88.83
# Best Test Accuracy = 89.08
#
# Epoch: 40
# Train Loss = 0.14965978493470974	 	Train Accuracy = 47368/50000 = 94.736
# Test Loss = 0.3457205791639376	 	Test accuracy = 8940/10000 = 89.4
# Best Test Accuracy = 89.4
#
# Epoch: 41
# Train Loss = 0.14496031870393802	 	Train Accuracy = 47457/50000 = 94.914
# Test Loss = 0.3914766047574297	 	Test accuracy = 8808/10000 = 88.08
# Best Test Accuracy = 89.4
#
# Epoch: 42
# Train Loss = 0.14069529985318252	 	Train Accuracy = 47553/50000 = 95.106
# Test Loss = 0.34468058468420293	 	Test accuracy = 8997/10000 = 89.97
# Best Test Accuracy = 89.97
#
# Epoch: 43
# Train Loss = 0.13241981184276777	 	Train Accuracy = 47650/50000 = 95.3
# Test Loss = 0.47070473922958855	 	Test accuracy = 8627/10000 = 86.27
# Best Test Accuracy = 89.97
#
# Epoch: 44
# Train Loss = 0.13209763132131008	 	Train Accuracy = 47671/50000 = 95.342
# Test Loss = 0.33312754653677157	 	Test accuracy = 9025/10000 = 90.25
# Best Test Accuracy = 90.25
#
# Epoch: 45
# Train Loss = 0.12701811667179208	 	Train Accuracy = 47769/50000 = 95.538
# Test Loss = 0.2989505870810038	 	Test accuracy = 9078/10000 = 90.78
# Best Test Accuracy = 90.78
#
# Epoch: 46
# Train Loss = 0.11896386876454591	 	Train Accuracy = 47903/50000 = 95.806
# Test Loss = 0.3575349363345134	 	Test accuracy = 8943/10000 = 89.43
# Best Test Accuracy = 90.78
#
# Epoch: 47
# Train Loss = 0.1133105877901206	 	Train Accuracy = 48050/50000 = 96.1
# Test Loss = 0.37879398446294327	 	Test accuracy = 8943/10000 = 89.43
# Best Test Accuracy = 90.78
#
# Epoch: 48
# Train Loss = 0.1069972853335883	 	Train Accuracy = 48158/50000 = 96.316
# Test Loss = 0.3177666969691651	 	Test accuracy = 9054/10000 = 90.54
# Best Test Accuracy = 90.78
#
# Epoch: 49
# Train Loss = 0.10228518684825781	 	Train Accuracy = 48187/50000 = 96.374
# Test Loss = 0.3536571871630753	 	Test accuracy = 8969/10000 = 89.69
# Best Test Accuracy = 90.78
#
# Epoch: 50
# Train Loss = 0.09758724380865731	 	Train Accuracy = 48353/50000 = 96.706
# Test Loss = 0.4222306546908391	 	Test accuracy = 8820/10000 = 88.2
# Best Test Accuracy = 90.78
#
# Epoch: 51
# Train Loss = 0.09802108923987964	 	Train Accuracy = 48304/50000 = 96.608
# Test Loss = 0.31581094125403636	 	Test accuracy = 9085/10000 = 90.85
# Best Test Accuracy = 90.85
#
# Epoch: 52
# Train Loss = 0.09234427879838382	 	Train Accuracy = 48429/50000 = 96.858
# Test Loss = 0.29307927191257477	 	Test accuracy = 9135/10000 = 91.35
# Best Test Accuracy = 91.35
#
# Epoch: 53
# Train Loss = 0.08957902306828962	 	Train Accuracy = 48461/50000 = 96.922
# Test Loss = 0.34934553023003323	 	Test accuracy = 9005/10000 = 90.05
# Best Test Accuracy = 91.35
#
# Epoch: 54
# Train Loss = 0.08385527555537803	 	Train Accuracy = 48600/50000 = 97.2
# Test Loss = 0.30172096164543416	 	Test accuracy = 9155/10000 = 91.55
# Best Test Accuracy = 91.55
#
# Epoch: 55
# Train Loss = 0.07543122849863051	 	Train Accuracy = 48731/50000 = 97.462
# Test Loss = 0.3058207276501233	 	Test accuracy = 9139/10000 = 91.39
# Best Test Accuracy = 91.55
#
# Epoch: 56
# Train Loss = 0.07767750630560129	 	Train Accuracy = 48667/50000 = 97.334
# Test Loss = 0.32593867786322966	 	Test accuracy = 9066/10000 = 90.66
# Best Test Accuracy = 91.55
#
# Epoch: 57
# Train Loss = 0.07179381336321307	 	Train Accuracy = 48789/50000 = 97.578
# Test Loss = 0.2999561467691313	 	Test accuracy = 9114/10000 = 91.14
# Best Test Accuracy = 91.55
#
# Epoch: 58
# Train Loss = 0.07001672697770397	 	Train Accuracy = 48808/50000 = 97.616
# Test Loss = 0.2992998382335977	 	Test accuracy = 9154/10000 = 91.54
# Best Test Accuracy = 91.55
#
# Epoch: 59
# Train Loss = 0.06325910273281966	 	Train Accuracy = 48929/50000 = 97.858
# Test Loss = 0.2937149804415582	 	Test accuracy = 9173/10000 = 91.73
# Best Test Accuracy = 91.73
#
# Epoch: 60
# Train Loss = 0.05824732828809096	 	Train Accuracy = 49024/50000 = 98.048
# Test Loss = 0.28913344791795637	 	Test accuracy = 9198/10000 = 91.98
# Best Test Accuracy = 91.98
#
# Epoch: 61
# Train Loss = 0.05829286274007138	 	Train Accuracy = 48998/50000 = 97.996
# Test Loss = 0.2966550036887579	 	Test accuracy = 9203/10000 = 92.03
# Best Test Accuracy = 92.03
#
# Epoch: 62
# Train Loss = 0.055733515864328655	 	Train Accuracy = 49099/50000 = 98.198
# Test Loss = 0.2888847426334514	 	Test accuracy = 9206/10000 = 92.06
# Best Test Accuracy = 92.06
#
# Epoch: 63
# Train Loss = 0.049974302051450745	 	Train Accuracy = 49168/50000 = 98.336
# Test Loss = 0.2863675775595858	 	Test accuracy = 9205/10000 = 92.05
# Best Test Accuracy = 92.06
#
# Epoch: 64
# Train Loss = 0.05056115426123142	 	Train Accuracy = 49176/50000 = 98.352
# Test Loss = 0.2895928557160534	 	Test accuracy = 9180/10000 = 91.8
# Best Test Accuracy = 92.06
#
# Epoch: 65
# Train Loss = 0.04739631455191566	 	Train Accuracy = 49214/50000 = 98.428
# Test Loss = 0.33868098211816594	 	Test accuracy = 9119/10000 = 91.19
# Best Test Accuracy = 92.06
#
# Epoch: 66
# Train Loss = 0.04111802231406083	 	Train Accuracy = 49345/50000 = 98.69
# Test Loss = 0.28071091946544524	 	Test accuracy = 9246/10000 = 92.46
# Best Test Accuracy = 92.46
#
# Epoch: 67
# Train Loss = 0.04295361107524932	 	Train Accuracy = 49296/50000 = 98.592
# Test Loss = 0.2975947289149972	 	Test accuracy = 9201/10000 = 92.01
# Best Test Accuracy = 92.46
#
# Epoch: 68
# Train Loss = 0.03640642589377358	 	Train Accuracy = 49405/50000 = 98.81
# Test Loss = 0.2813439046657538	 	Test accuracy = 9223/10000 = 92.23
# Best Test Accuracy = 92.46
#
# Epoch: 69
# Train Loss = 0.033392399252937806	 	Train Accuracy = 49483/50000 = 98.966
# Test Loss = 0.2782361824301225	 	Test accuracy = 9261/10000 = 92.61
# Best Test Accuracy = 92.61
#
# Epoch: 70
# Train Loss = 0.03335697423604786	 	Train Accuracy = 49472/50000 = 98.944
# Test Loss = 0.2774658485115329	 	Test accuracy = 9255/10000 = 92.55
# Best Test Accuracy = 92.61
#
# Epoch: 71
# Train Loss = 0.028992206544217552	 	Train Accuracy = 49555/50000 = 99.11
# Test Loss = 0.27044161710935305	 	Test accuracy = 9274/10000 = 92.74
# Best Test Accuracy = 92.74
#
# Epoch: 72
# Train Loss = 0.02744996362863599	 	Train Accuracy = 49573/50000 = 99.146
# Test Loss = 0.2747472544448285	 	Test accuracy = 9253/10000 = 92.53
# Best Test Accuracy = 92.74
#
# Epoch: 73
# Train Loss = 0.024952451816386046	 	Train Accuracy = 49631/50000 = 99.262
# Test Loss = 0.2732498691051821	 	Test accuracy = 9264/10000 = 92.64
# Best Test Accuracy = 92.74
#
# Epoch: 74
# Train Loss = 0.02272863792912925	 	Train Accuracy = 49667/50000 = 99.334
# Test Loss = 0.2722611277352405	 	Test accuracy = 9291/10000 = 92.91
# Best Test Accuracy = 92.91
#
# Epoch: 75
# Train Loss = 0.023376792301292842	 	Train Accuracy = 49647/50000 = 99.294
# Test Loss = 0.2746362567325182	 	Test accuracy = 9267/10000 = 92.67
# Best Test Accuracy = 92.91
#
# Epoch: 76
# Train Loss = 0.021250099365901956	 	Train Accuracy = 49710/50000 = 99.42
# Test Loss = 0.268201886664463	 	Test accuracy = 9292/10000 = 92.92
# Best Test Accuracy = 92.92
#
# Epoch: 77
# Train Loss = 0.01900543744587685	 	Train Accuracy = 49739/50000 = 99.478
# Test Loss = 0.27099409944648983	 	Test accuracy = 9270/10000 = 92.7
# Best Test Accuracy = 92.92
#
# Epoch: 78
# Train Loss = 0.01877170093738667	 	Train Accuracy = 49724/50000 = 99.448
# Test Loss = 0.265175543348246	 	Test accuracy = 9296/10000 = 92.96
# Best Test Accuracy = 92.96
#
# Epoch: 79
# Train Loss = 0.01711828641526763	 	Train Accuracy = 49768/50000 = 99.536
# Test Loss = 0.2610092504020733	 	Test accuracy = 9304/10000 = 93.04
# Best Test Accuracy = 93.04
#
# Epoch: 80
# Train Loss = 0.016678073466695902	 	Train Accuracy = 49788/50000 = 99.576
# Test Loss = 0.25984627357389356	 	Test accuracy = 9297/10000 = 92.97
# Best Test Accuracy = 93.04
#
# Epoch: 81
# Train Loss = 0.01605703250226348	 	Train Accuracy = 49778/50000 = 99.556
# Test Loss = 0.2623464157686958	 	Test accuracy = 9307/10000 = 93.07
# Best Test Accuracy = 93.07
#
# Epoch: 82
# Train Loss = 0.014620126049091462	 	Train Accuracy = 49811/50000 = 99.622
# Test Loss = 0.2656077610069438	 	Test accuracy = 9319/10000 = 93.19
# Best Test Accuracy = 93.19
#
# Epoch: 83
# Train Loss = 0.014669207140893849	 	Train Accuracy = 49798/50000 = 99.596
# Test Loss = 0.25929968417445315	 	Test accuracy = 9304/10000 = 93.04
# Best Test Accuracy = 93.19
#
# Epoch: 84
# Train Loss = 0.013606731730151226	 	Train Accuracy = 49813/50000 = 99.626
# Test Loss = 0.26147805408963676	 	Test accuracy = 9316/10000 = 93.16
# Best Test Accuracy = 93.19
#
# Epoch: 85
# Train Loss = 0.012383121489177999	 	Train Accuracy = 49844/50000 = 99.688
# Test Loss = 0.26579717254336876	 	Test accuracy = 9314/10000 = 93.14
# Best Test Accuracy = 93.19
#
# Epoch: 86
# Train Loss = 0.011957325998817563	 	Train Accuracy = 49843/50000 = 99.686
# Test Loss = 0.26741878395970864	 	Test accuracy = 9323/10000 = 93.23
# Best Test Accuracy = 93.23
#
# Epoch: 87
# Train Loss = 0.011982965419459564	 	Train Accuracy = 49843/50000 = 99.686
# Test Loss = 0.26077141376990304	 	Test accuracy = 9325/10000 = 93.25
# Best Test Accuracy = 93.25
#
# Epoch: 88
# Train Loss = 0.010979736569787726	 	Train Accuracy = 49865/50000 = 99.73
# Test Loss = 0.2603639495335048	 	Test accuracy = 9330/10000 = 93.3
# Best Test Accuracy = 93.3
#
# Epoch: 89
# Train Loss = 0.010970330530958599	 	Train Accuracy = 49870/50000 = 99.74
# Test Loss = 0.25884430402819114	 	Test accuracy = 9327/10000 = 93.27
# Best Test Accuracy = 93.3
#
# Epoch: 90
# Train Loss = 0.010928771422539963	 	Train Accuracy = 49858/50000 = 99.716
# Test Loss = 0.26074065456662	 	Test accuracy = 9330/10000 = 93.3
# Best Test Accuracy = 93.3
#
# Epoch: 91
# Train Loss = 0.010890461452950811	 	Train Accuracy = 49865/50000 = 99.73
# Test Loss = 0.2579734502713891	 	Test accuracy = 9338/10000 = 93.38
# Best Test Accuracy = 93.38
#
# Epoch: 92
# Train Loss = 0.010108579896971621	 	Train Accuracy = 49883/50000 = 99.766
# Test Loss = 0.25905940285589124	 	Test accuracy = 9322/10000 = 93.22
# Best Test Accuracy = 93.38
#
# Epoch: 93
# Train Loss = 0.010323460190318753	 	Train Accuracy = 49875/50000 = 99.75
# Test Loss = 0.2627700621002837	 	Test accuracy = 9339/10000 = 93.39
# Best Test Accuracy = 93.39
#
# Epoch: 94
# Train Loss = 0.010125379519039274	 	Train Accuracy = 49891/50000 = 99.782
# Test Loss = 0.2597540308591686	 	Test accuracy = 9327/10000 = 93.27
# Best Test Accuracy = 93.39
#
# Epoch: 95
# Train Loss = 0.009717925598778192	 	Train Accuracy = 49881/50000 = 99.762
# Test Loss = 0.26003597705047343	 	Test accuracy = 9329/10000 = 93.29
# Best Test Accuracy = 93.39
#
# Epoch: 96
# Train Loss = 0.00930326334331804	 	Train Accuracy = 49904/50000 = 99.808
# Test Loss = 0.25912217211119737	 	Test accuracy = 9333/10000 = 93.33
# Best Test Accuracy = 93.39
#
# Epoch: 97
# Train Loss = 0.010235753438263998	 	Train Accuracy = 49883/50000 = 99.766
# Test Loss = 0.2577817911588693	 	Test accuracy = 9328/10000 = 93.28
# Best Test Accuracy = 93.39
#
# Epoch: 98
# Train Loss = 0.010360616930376957	 	Train Accuracy = 49886/50000 = 99.772
# Test Loss = 0.25909431278705597	 	Test accuracy = 9333/10000 = 93.33
# Best Test Accuracy = 93.39
#
# Epoch: 99
# Train Loss = 0.010177799268289829	 	Train Accuracy = 49877/50000 = 99.754
# Test Loss = 0.25944125227913073	 	Test accuracy = 9329/10000 = 93.29
# Best Test Accuracy = 93.39
#
# Epoch: 100
# Train Loss = 0.010283972828915758	 	Train Accuracy = 49874/50000 = 99.748
# Test Loss = 0.26037660410887076	 	Test accuracy = 9340/10000 = 93.4
# Best Test Accuracy = 93.4

# %%
# Plotting Losses and Accuracies for the training process (CASE - 1)

plot_metrics(train_accs, test_accs, train_losses, test_losses, 
             max(range(len(test_accs)), key = test_accs.__getitem__), 
             max(test_accs))

# %% [markdown]
# ### CASE - 2: lr = 0.1, momentum = 0.0005, weight_decay =  5e-4

# %%
# Initializing network and setting optimizer and Learning Rate Decay (CASE - 2)

net = initNetwork()

optimizer = optim.SGD(net.parameters(), lr = 0.1, momentum = 0.0005, 
                      weight_decay = 5e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 
                                                       T_max = EPOCHS)

# %%
# Training the ResNet18 (CASE - 2)

best_acc = 0

train_accs = []
train_losses = []

test_accs = []
test_losses = []

for epoch in range(EPOCHS):
  
  train(epoch)
  acc = test(epoch)

  if acc > best_acc:
      best_acc = acc
      torch.save(net.state_dict(), '/content/models/resnet2.pt')
  
  print("Best Test Accuracy = " + str(best_acc))
  scheduler.step()
# Out:
# Epoch: 1
# Train Loss = 1.6294577197955393	 	Train Accuracy = 20232/50000 = 40.464
# Test Loss = 1.6227834828292267	 	Test accuracy = 4621/10000 = 46.21
# Best Test Accuracy = 46.21
#
# Epoch: 2
# Train Loss = 1.1161082045501456	 	Train Accuracy = 30005/50000 = 60.01
# Test Loss = 1.191361959976486	 	Test accuracy = 6019/10000 = 60.19
# Best Test Accuracy = 60.19
#
# Epoch: 3
# Train Loss = 0.8747305924935109	 	Train Accuracy = 34498/50000 = 68.996
# Test Loss = 1.6405949260615096	 	Test accuracy = 5495/10000 = 54.95
# Best Test Accuracy = 60.19
#
# Epoch: 4
# Train Loss = 0.7409689566668343	 	Train Accuracy = 37001/50000 = 74.002
# Test Loss = 0.7274376795261721	 	Test accuracy = 7531/10000 = 75.31
# Best Test Accuracy = 75.31
#
# Epoch: 5
# Train Loss = 0.6534908946670229	 	Train Accuracy = 38613/50000 = 77.226
# Test Loss = 1.0586483629443977	 	Test accuracy = 6852/10000 = 68.52
# Best Test Accuracy = 75.31
#
# Epoch: 6
# Train Loss = 0.5942611076947674	 	Train Accuracy = 39581/50000 = 79.162
# Test Loss = 0.7124936399580557	 	Test accuracy = 7699/10000 = 76.99
# Best Test Accuracy = 76.99
#
# Epoch: 7
# Train Loss = 0.5435814529733585	 	Train Accuracy = 40498/50000 = 80.996
# Test Loss = 0.6537791373608988	 	Test accuracy = 7819/10000 = 78.19
# Best Test Accuracy = 78.19
#
# Epoch: 8
# Train Loss = 0.5091931681956172	 	Train Accuracy = 41127/50000 = 82.254
# Test Loss = 0.6375016913383822	 	Test accuracy = 7961/10000 = 79.61
# Best Test Accuracy = 79.61
#
# Epoch: 9
# Train Loss = 0.47255401980236666	 	Train Accuracy = 41718/50000 = 83.436
# Test Loss = 0.5248534339892713	 	Test accuracy = 8219/10000 = 82.19
# Best Test Accuracy = 82.19
#
# Epoch: 10
# Train Loss = 0.4459437711921799	 	Train Accuracy = 42256/50000 = 84.512
# Test Loss = 0.6108301274384125	 	Test accuracy = 8000/10000 = 80.0
# Best Test Accuracy = 82.19
#
# Epoch: 11
# Train Loss = 0.4197519497798227	 	Train Accuracy = 42773/50000 = 85.546
# Test Loss = 0.4890967294385162	 	Test accuracy = 8386/10000 = 83.86
# Best Test Accuracy = 83.86
#
# Epoch: 12
# Train Loss = 0.39786983035561985	 	Train Accuracy = 43036/50000 = 86.072
# Test Loss = 0.5200367483157146	 	Test accuracy = 8308/10000 = 83.08
# Best Test Accuracy = 83.86
#
# Epoch: 13
# Train Loss = 0.38190364795725057	 	Train Accuracy = 43291/50000 = 86.582
# Test Loss = 0.5757334854783891	 	Test accuracy = 8164/10000 = 81.64
# Best Test Accuracy = 83.86
#
# Epoch: 14
# Train Loss = 0.36335203177331354	 	Train Accuracy = 43671/50000 = 87.342
# Test Loss = 0.4538883600808397	 	Test accuracy = 8467/10000 = 84.67
# Best Test Accuracy = 84.67
#
# Epoch: 15
# Train Loss = 0.34535120637215616	 	Train Accuracy = 43966/50000 = 87.932
# Test Loss = 0.4770456790169583	 	Test accuracy = 8442/10000 = 84.42
# Best Test Accuracy = 84.67
#
# Epoch: 16
# Train Loss = 0.32867933097093	 	Train Accuracy = 44234/50000 = 88.468
# Test Loss = 0.47423030304003366	 	Test accuracy = 8453/10000 = 84.53
# Best Test Accuracy = 84.67
#
# Epoch: 17
# Train Loss = 0.3198371596653443	 	Train Accuracy = 44362/50000 = 88.724
# Test Loss = 0.3783883760812916	 	Test accuracy = 8739/10000 = 87.39
# Best Test Accuracy = 87.39
#
# Epoch: 18
# Train Loss = 0.3033862706188046	 	Train Accuracy = 44769/50000 = 89.538
# Test Loss = 0.36831223040441924	 	Test accuracy = 8799/10000 = 87.99
# Best Test Accuracy = 87.99
#
# Epoch: 19
# Train Loss = 0.29057785350343457	 	Train Accuracy = 44850/50000 = 89.7
# Test Loss = 0.4573170210741743	 	Test accuracy = 8565/10000 = 85.65
# Best Test Accuracy = 87.99
#
# Epoch: 20
# Train Loss = 0.278303784253957	 	Train Accuracy = 45157/50000 = 90.314
# Test Loss = 0.42801387645775757	 	Test accuracy = 8652/10000 = 86.52
# Best Test Accuracy = 87.99
#
# Epoch: 21
# Train Loss = 0.27040403883170594	 	Train Accuracy = 45228/50000 = 90.456
# Test Loss = 0.4273853417061552	 	Test accuracy = 8664/10000 = 86.64
# Best Test Accuracy = 87.99
#
# Epoch: 22
# Train Loss = 0.26245485598702567	 	Train Accuracy = 45415/50000 = 90.83
# Test Loss = 0.37967154553419424	 	Test accuracy = 8800/10000 = 88.0
# Best Test Accuracy = 88.0
#
# Epoch: 23

# %%
# Plotting Losses and Accuracies for the training process (CASE - 2)

plot_metrics(train_accs, test_accs, train_losses, test_losses, 
             max(range(len(test_accs)), key = test_accs.__getitem__), 
             max(test_accs))

# %% [markdown]
# ### CASE - 3: lr = 0.075, momentum = 0.0005, weight_decay =  5e-4

# %%
# Initializing network and setting optimizer and Learning Rate Decay (CASE - 3)

net = initNetwork()

optimizer = optim.SGD(net.parameters(), lr = 0.075, momentum = 0.0005, 
                      weight_decay = 5e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 
                                                       T_max = EPOCHS)

# %%
# Training the ResNet18 (CASE - 3)

best_acc = 0

train_accs = []
train_losses = []

test_accs = []
test_losses = []

for epoch in range(EPOCHS):
  
  train(epoch)
  acc = test(epoch)

  if acc > best_acc:
      best_acc = acc
      torch.save(net.state_dict(), '/content/models/resnet3.pt')
  
  print("Best Test Accuracy = " + str(best_acc))
  scheduler.step()
# Out:
# Epoch: 1
# Train Loss = 1.5824989929528492	 	Train Accuracy = 21036/50000 = 42.072
# Test Loss = 1.5430904657025881	 	Test accuracy = 4785/10000 = 47.85
# Best Test Accuracy = 47.85
#
# Epoch: 2
# Train Loss = 1.0937644549647865	 	Train Accuracy = 30439/50000 = 60.878
# Test Loss = 1.1011352403254449	 	Test accuracy = 6177/10000 = 61.77
# Best Test Accuracy = 61.77
#
# Epoch: 3
# Train Loss = 0.88575214467695	 	Train Accuracy = 34326/50000 = 68.652
# Test Loss = 1.0040269565733173	 	Test accuracy = 6504/10000 = 65.04
# Best Test Accuracy = 65.04
#
# Epoch: 4
# Train Loss = 0.7482800626998667	 	Train Accuracy = 36948/50000 = 73.896
# Test Loss = 0.7622878347771077	 	Test accuracy = 7398/10000 = 73.98
# Best Test Accuracy = 73.98
#
# Epoch: 5
# Train Loss = 0.6622397296721368	 	Train Accuracy = 38395/50000 = 76.79
# Test Loss = 0.7476264615602131	 	Test accuracy = 7547/10000 = 75.47
# Best Test Accuracy = 75.47
#
# Epoch: 6
# Train Loss = 0.5942783796268961	 	Train Accuracy = 39514/50000 = 79.028
# Test Loss = 0.6012245492090152	 	Test accuracy = 7953/10000 = 79.53
# Best Test Accuracy = 79.53
#
# Epoch: 7
# Train Loss = 0.5444111168536994	 	Train Accuracy = 40508/50000 = 81.016
# Test Loss = 0.6379137684272814	 	Test accuracy = 7920/10000 = 79.2
# Best Test Accuracy = 79.53
#
# Epoch: 8
# Train Loss = 0.5078421494235164	 	Train Accuracy = 41133/50000 = 82.266
# Test Loss = 0.600964131611812	 	Test accuracy = 7995/10000 = 79.95
# Best Test Accuracy = 79.95
#
# Epoch: 9
# Train Loss = 0.4757105564827199	 	Train Accuracy = 41695/50000 = 83.39
# Test Loss = 0.5877416507352756	 	Test accuracy = 8056/10000 = 80.56
# Best Test Accuracy = 80.56
#
# Epoch: 10
# Train Loss = 0.44883253255768507	 	Train Accuracy = 42187/50000 = 84.374
# Test Loss = 0.5045318728006338	 	Test accuracy = 8309/10000 = 83.09
# Best Test Accuracy = 83.09
#
# Epoch: 11
# Train Loss = 0.42193768285881833	 	Train Accuracy = 42550/50000 = 85.1
# Test Loss = 0.608046559216101	 	Test accuracy = 8008/10000 = 80.08
# Best Test Accuracy = 83.09
#
# Epoch: 12
# Train Loss = 0.4055608805945462	 	Train Accuracy = 42994/50000 = 85.988
# Test Loss = 0.6186546290977092	 	Test accuracy = 8061/10000 = 80.61
# Best Test Accuracy = 83.09
#
# Epoch: 13
# Train Loss = 0.3810591954175773	 	Train Accuracy = 43340/50000 = 86.68
# Test Loss = 0.5334894919319998	 	Test accuracy = 8300/10000 = 83.0
# Best Test Accuracy = 83.09
#
# Epoch: 14
# Train Loss = 0.36521708504165834	 	Train Accuracy = 43659/50000 = 87.318
# Test Loss = 0.6595182197192048	 	Test accuracy = 8018/10000 = 80.18
# Best Test Accuracy = 83.09
#
# Epoch: 15
# Train Loss = 0.3468178573166928	 	Train Accuracy = 43949/50000 = 87.898
# Test Loss = 0.46841340427157246	 	Test accuracy = 8491/10000 = 84.91
# Best Test Accuracy = 84.91
#
# Epoch: 16
# Train Loss = 0.3348532995909376	 	Train Accuracy = 44151/50000 = 88.302
# Test Loss = 0.43130845321884637	 	Test accuracy = 8586/10000 = 85.86
# Best Test Accuracy = 85.86
#
# Epoch: 17
# Train Loss = 0.3169651425174435	 	Train Accuracy = 44411/50000 = 88.822
# Test Loss = 0.4612225769441339	 	Test accuracy = 8508/10000 = 85.08
# Best Test Accuracy = 85.86
#
# Epoch: 18
# Train Loss = 0.30118513896184806	 	Train Accuracy = 44708/50000 = 89.416
# Test Loss = 0.43739235155944584	 	Test accuracy = 8593/10000 = 85.93
# Best Test Accuracy = 85.93
#
# Epoch: 19
# Train Loss = 0.2949357393300137	 	Train Accuracy = 44783/50000 = 89.566
# Test Loss = 0.4015589927947974	 	Test accuracy = 8722/10000 = 87.22
# Best Test Accuracy = 87.22
#
# Epoch: 20
# Train Loss = 0.2809121615975104	 	Train Accuracy = 45052/50000 = 90.104
# Test Loss = 0.5547370295735854	 	Test accuracy = 8313/10000 = 83.13
# Best Test Accuracy = 87.22
#
# Epoch: 21
# Train Loss = 0.2742924365736639	 	Train Accuracy = 45137/50000 = 90.274
# Test Loss = 0.5519714570498164	 	Test accuracy = 8323/10000 = 83.23
# Best Test Accuracy = 87.22
#
# Epoch: 22
# Train Loss = 0.26086624904209393	 	Train Accuracy = 45485/50000 = 90.97
# Test Loss = 0.5721354997610744	 	Test accuracy = 8301/10000 = 83.01
# Best Test Accuracy = 87.22
#
# Epoch: 23
# Train Loss = 0.24934550233737893	 	Train Accuracy = 45528/50000 = 91.056
# Test Loss = 0.45515397209909897	 	Test accuracy = 8558/10000 = 85.58
# Best Test Accuracy = 87.22
#
# Epoch: 24
# Train Loss = 0.24316467830668326	 	Train Accuracy = 45689/50000 = 91.378
# Test Loss = 0.411733106344561	 	Test accuracy = 8756/10000 = 87.56
# Best Test Accuracy = 87.56
#
# Epoch: 25
# Train Loss = 0.2343993778042781	 	Train Accuracy = 45957/50000 = 91.914
# Test Loss = 0.42094967014427426	 	Test accuracy = 8700/10000 = 87.0
# Best Test Accuracy = 87.56
#
# Epoch: 26
# Train Loss = 0.22578952888317425	 	Train Accuracy = 46029/50000 = 92.058
# Test Loss = 0.39280930255787283	 	Test accuracy = 8802/10000 = 88.02
# Best Test Accuracy = 88.02
#
# Epoch: 27
# Train Loss = 0.21666764075417652	 	Train Accuracy = 46278/50000 = 92.556
# Test Loss = 0.38581429591661764	 	Test accuracy = 8771/10000 = 87.71
# Best Test Accuracy = 88.02
#
# Epoch: 28
# Train Loss = 0.2107649781667363	 	Train Accuracy = 46274/50000 = 92.548
# Test Loss = 0.3732308019188386	 	Test accuracy = 8869/10000 = 88.69
# Best Test Accuracy = 88.69
#
# Epoch: 29
# Train Loss = 0.20490177415902047	 	Train Accuracy = 46393/50000 = 92.786
# Test Loss = 0.35389325984671144	 	Test accuracy = 8881/10000 = 88.81
# Best Test Accuracy = 88.81
#
# Epoch: 30
# Train Loss = 0.19783974452244352	 	Train Accuracy = 46499/50000 = 92.998
# Test Loss = 0.40004776776591433	 	Test accuracy = 8788/10000 = 87.88
# Best Test Accuracy = 88.81
#
# Epoch: 31
# Train Loss = 0.19106147064805945	 	Train Accuracy = 46614/50000 = 93.228
# Test Loss = 0.37506548192682143	 	Test accuracy = 8887/10000 = 88.87
# Best Test Accuracy = 88.87
#
# Epoch: 32
# Train Loss = 0.18410430143556328	 	Train Accuracy = 46746/50000 = 93.492
# Test Loss = 0.3743704972387869	 	Test accuracy = 8852/10000 = 88.52
# Best Test Accuracy = 88.87
#
# Epoch: 33
# Train Loss = 0.1770104496737423	 	Train Accuracy = 46863/50000 = 93.726
# Test Loss = 0.3314087390899658	 	Test accuracy = 8980/10000 = 89.8
# Best Test Accuracy = 89.8
#
# Epoch: 34
# Train Loss = 0.16836181040996176	 	Train Accuracy = 46954/50000 = 93.908
# Test Loss = 0.33536039170207854	 	Test accuracy = 8992/10000 = 89.92
# Best Test Accuracy = 89.92
#
# Epoch: 35
# Train Loss = 0.1616758019437113	 	Train Accuracy = 47163/50000 = 94.326
# Test Loss = 0.33691981585719916	 	Test accuracy = 8945/10000 = 89.45
# Best Test Accuracy = 89.92
#
# Epoch: 36
# Train Loss = 0.16024655863032927	 	Train Accuracy = 47104/50000 = 94.208
# Test Loss = 0.39360009133815765	 	Test accuracy = 8840/10000 = 88.4
# Best Test Accuracy = 89.92
#
# Epoch: 37
# Train Loss = 0.15436295720050708	 	Train Accuracy = 47319/50000 = 94.638
# Test Loss = 0.30768121514893787	 	Test accuracy = 9054/10000 = 90.54
# Best Test Accuracy = 90.54
#
# Epoch: 38
# Train Loss = 0.1465126895024191	 	Train Accuracy = 47392/50000 = 94.784
# Test Loss = 0.3539456300720384	 	Test accuracy = 8962/10000 = 89.62
# Best Test Accuracy = 90.54
#
# Epoch: 39
# Train Loss = 0.14122147557070797	 	Train Accuracy = 47474/50000 = 94.948
# Test Loss = 0.3300613359182696	 	Test accuracy = 9007/10000 = 90.07
# Best Test Accuracy = 90.54
#
# Epoch: 40
# Train Loss = 0.14081176487571748	 	Train Accuracy = 47503/50000 = 95.006
# Test Loss = 0.3780687036393564	 	Test accuracy = 8887/10000 = 88.87
# Best Test Accuracy = 90.54
#
# Epoch: 41
# Train Loss = 0.1259356848133342	 	Train Accuracy = 47801/50000 = 95.602
# Test Loss = 0.32080229362355	 	Test accuracy = 9055/10000 = 90.55
# Best Test Accuracy = 90.55
#
# Epoch: 42
# Train Loss = 0.1271470138979385	 	Train Accuracy = 47729/50000 = 95.458
# Test Loss = 0.329447647061529	 	Test accuracy = 9075/10000 = 90.75
# Best Test Accuracy = 90.75
#
# Epoch: 43
# Train Loss = 0.1225127985086435	 	Train Accuracy = 47789/50000 = 95.578
# Test Loss = 0.31904194650204876	 	Test accuracy = 9026/10000 = 90.26
# Best Test Accuracy = 90.75
#
# Epoch: 44
# Train Loss = 0.1192435418801082	 	Train Accuracy = 47925/50000 = 95.85
# Test Loss = 0.32371698018116285	 	Test accuracy = 9059/10000 = 90.59
# Best Test Accuracy = 90.75
#
# Epoch: 45
# Train Loss = 0.11036888727694369	 	Train Accuracy = 48069/50000 = 96.138
# Test Loss = 0.3361434762047816	 	Test accuracy = 9025/10000 = 90.25
# Best Test Accuracy = 90.75
#
# Epoch: 46
# Train Loss = 0.10745348237321505	 	Train Accuracy = 48073/50000 = 96.146
# Test Loss = 0.3707544126465351	 	Test accuracy = 8973/10000 = 89.73
# Best Test Accuracy = 90.75
#
# Epoch: 47
# Train Loss = 0.1020842990302064	 	Train Accuracy = 48212/50000 = 96.424
# Test Loss = 0.3446541478550887	 	Test accuracy = 9047/10000 = 90.47
# Best Test Accuracy = 90.75
#
# Epoch: 48
# Train Loss = 0.09583768046572995	 	Train Accuracy = 48283/50000 = 96.566
# Test Loss = 0.3499566127982321	 	Test accuracy = 9025/10000 = 90.25
# Best Test Accuracy = 90.75
#
# Epoch: 49
# Train Loss = 0.09447058779008859	 	Train Accuracy = 48363/50000 = 96.726
# Test Loss = 0.30956540237876434	 	Test accuracy = 9104/10000 = 91.04
# Best Test Accuracy = 91.04
#
# Epoch: 50
# Train Loss = 0.09026055793037348	 	Train Accuracy = 48453/50000 = 96.906
# Test Loss = 0.3705167574218557	 	Test accuracy = 9006/10000 = 90.06
# Best Test Accuracy = 91.04
#
# Epoch: 51
# Train Loss = 0.08398356856039875	 	Train Accuracy = 48560/50000 = 97.12
# Test Loss = 0.39768924639572073	 	Test accuracy = 8883/10000 = 88.83
# Best Test Accuracy = 91.04
#
# Epoch: 52
# Train Loss = 0.0809676796960099	 	Train Accuracy = 48596/50000 = 97.192
# Test Loss = 0.3082694165125678	 	Test accuracy = 9135/10000 = 91.35
# Best Test Accuracy = 91.35
#
# Epoch: 53
# Train Loss = 0.08098318453049264	 	Train Accuracy = 48600/50000 = 97.2
# Test Loss = 0.3083731645270239	 	Test accuracy = 9164/10000 = 91.64
# Best Test Accuracy = 91.64
#
# Epoch: 54
# Train Loss = 0.07416490895097214	 	Train Accuracy = 48757/50000 = 97.514
# Test Loss = 0.32934777514089514	 	Test accuracy = 9111/10000 = 91.11
# Best Test Accuracy = 91.64
#
# Epoch: 55
# Train Loss = 0.06936257917557836	 	Train Accuracy = 48818/50000 = 97.636
# Test Loss = 0.3178044746901038	 	Test accuracy = 9138/10000 = 91.38
# Best Test Accuracy = 91.64
#
# Epoch: 56
# Train Loss = 0.06711810042657664	 	Train Accuracy = 48815/50000 = 97.63
# Test Loss = 0.3261147363087799	 	Test accuracy = 9123/10000 = 91.23
# Best Test Accuracy = 91.64
#
# Epoch: 57
# Train Loss = 0.06331020542908736	 	Train Accuracy = 48935/50000 = 97.87
# Test Loss = 0.31806475291901	 	Test accuracy = 9142/10000 = 91.42
# Best Test Accuracy = 91.64
#
# Epoch: 58
# Train Loss = 0.061336939597068846	 	Train Accuracy = 48970/50000 = 97.94
# Test Loss = 0.3165320529590679	 	Test accuracy = 9161/10000 = 91.61
# Best Test Accuracy = 91.64
#
# Epoch: 59
# Train Loss = 0.056378604573866974	 	Train Accuracy = 49047/50000 = 98.094
# Test Loss = 0.3000164121578011	 	Test accuracy = 9200/10000 = 92.0
# Best Test Accuracy = 92.0
#
# Epoch: 60
# Train Loss = 0.05315309366130311	 	Train Accuracy = 49122/50000 = 98.244
# Test Loss = 0.3082178633990167	 	Test accuracy = 9175/10000 = 91.75
# Best Test Accuracy = 92.0
#
# Epoch: 61
# Train Loss = 0.05125284143020887	 	Train Accuracy = 49161/50000 = 98.322
# Test Loss = 0.3171003774940213	 	Test accuracy = 9180/10000 = 91.8
# Best Test Accuracy = 92.0
#
# Epoch: 62
# Train Loss = 0.04917084561336948	 	Train Accuracy = 49183/50000 = 98.366
# Test Loss = 0.30259849338591854	 	Test accuracy = 9151/10000 = 91.51
# Best Test Accuracy = 92.0
#
# Epoch: 63
# Train Loss = 0.04587117990578913	 	Train Accuracy = 49259/50000 = 98.518
# Test Loss = 0.3092202753583087	 	Test accuracy = 9169/10000 = 91.69
# Best Test Accuracy = 92.0
#
# Epoch: 64
# Train Loss = 0.04165320656598186	 	Train Accuracy = 49323/50000 = 98.646
# Test Loss = 0.30400068935336944	 	Test accuracy = 9196/10000 = 91.96
# Best Test Accuracy = 92.0
#
# Epoch: 65
# Train Loss = 0.04401468072215195	 	Train Accuracy = 49262/50000 = 98.524
# Test Loss = 0.28964519048038917	 	Test accuracy = 9236/10000 = 92.36
# Best Test Accuracy = 92.36
#
# Epoch: 66
# Train Loss = 0.03907705408513851	 	Train Accuracy = 49393/50000 = 98.786
# Test Loss = 0.2887114348668086	 	Test accuracy = 9250/10000 = 92.5
# Best Test Accuracy = 92.5
#
# Epoch: 67
# Train Loss = 0.034885190763151094	 	Train Accuracy = 49453/50000 = 98.906
# Test Loss = 0.2968035340309143	 	Test accuracy = 9245/10000 = 92.45
# Best Test Accuracy = 92.5
#
# Epoch: 68
# Train Loss = 0.035840910761748127	 	Train Accuracy = 49434/50000 = 98.868
# Test Loss = 0.3146770345636561	 	Test accuracy = 9170/10000 = 91.7
# Best Test Accuracy = 92.5
#
# Epoch: 69
# Train Loss = 0.03194261126129714	 	Train Accuracy = 49483/50000 = 98.966
# Test Loss = 0.28957034958691535	 	Test accuracy = 9227/10000 = 92.27
# Best Test Accuracy = 92.5
#
# Epoch: 70
# Train Loss = 0.030108710967690286	 	Train Accuracy = 49548/50000 = 99.096
# Test Loss = 0.28915263165401506	 	Test accuracy = 9259/10000 = 92.59
# Best Test Accuracy = 92.59
#
# Epoch: 71
# Train Loss = 0.02928359790102524	 	Train Accuracy = 49555/50000 = 99.11
# Test Loss = 0.3037077488401268	 	Test accuracy = 9214/10000 = 92.14
# Best Test Accuracy = 92.59
#
# Epoch: 72
# Train Loss = 0.028573964229401422	 	Train Accuracy = 49545/50000 = 99.09
# Test Loss = 0.28701260940560813	 	Test accuracy = 9254/10000 = 92.54
# Best Test Accuracy = 92.59
#
# Epoch: 73
# Train Loss = 0.0258815898619535	 	Train Accuracy = 49618/50000 = 99.236
# Test Loss = 0.28281821055880074	 	Test accuracy = 9277/10000 = 92.77
# Best Test Accuracy = 92.77
#
# Epoch: 74
# Train Loss = 0.02388007638921194	 	Train Accuracy = 49665/50000 = 99.33
# Test Loss = 0.2868994027376175	 	Test accuracy = 9260/10000 = 92.6
# Best Test Accuracy = 92.77
#
# Epoch: 75
# Train Loss = 0.0230947927764767	 	Train Accuracy = 49663/50000 = 99.326
# Test Loss = 0.28935902777917777	 	Test accuracy = 9260/10000 = 92.6
# Best Test Accuracy = 92.77
#
# Epoch: 76
# Train Loss = 0.021688688371349556	 	Train Accuracy = 49676/50000 = 99.352
# Test Loss = 0.2890339013707789	 	Test accuracy = 9262/10000 = 92.62
# Best Test Accuracy = 92.77
#
# Epoch: 77
# Train Loss = 0.02154472560676582	 	Train Accuracy = 49683/50000 = 99.366
# Test Loss = 0.28613467901190626	 	Test accuracy = 9266/10000 = 92.66
# Best Test Accuracy = 92.77
#
# Epoch: 78
# Train Loss = 0.020329446802773248	 	Train Accuracy = 49704/50000 = 99.408
# Test Loss = 0.2812704037450537	 	Test accuracy = 9279/10000 = 92.79
# Best Test Accuracy = 92.79
#
# Epoch: 79
# Train Loss = 0.0186741312202352	 	Train Accuracy = 49742/50000 = 99.484
# Test Loss = 0.28488857016155994	 	Test accuracy = 9304/10000 = 93.04
# Best Test Accuracy = 93.04
#
# Epoch: 80
# Train Loss = 0.017896065143677774	 	Train Accuracy = 49759/50000 = 99.518
# Test Loss = 0.2728598721419709	 	Test accuracy = 9302/10000 = 93.02
# Best Test Accuracy = 93.04
#
# Epoch: 81
# Train Loss = 0.01808239680910221	 	Train Accuracy = 49748/50000 = 99.496
# Test Loss = 0.2760773094583161	 	Test accuracy = 9305/10000 = 93.05
# Best Test Accuracy = 93.05
#
# Epoch: 82
# Train Loss = 0.016719235729573824	 	Train Accuracy = 49787/50000 = 99.574
# Test Loss = 0.2792277767122546	 	Test accuracy = 9298/10000 = 92.98
# Best Test Accuracy = 93.05
#
# Epoch: 83
# Train Loss = 0.016114815809678218	 	Train Accuracy = 49783/50000 = 99.566
# Test Loss = 0.27829935382815857	 	Test accuracy = 9302/10000 = 93.02
# Best Test Accuracy = 93.05
#
# Epoch: 84
# Train Loss = 0.01619171664414122	 	Train Accuracy = 49783/50000 = 99.566
# Test Loss = 0.27392886805383465	 	Test accuracy = 9297/10000 = 92.97
# Best Test Accuracy = 93.05
#
# Epoch: 85
# Train Loss = 0.014906660421415592	 	Train Accuracy = 49816/50000 = 99.632
# Test Loss = 0.27872840682917005	 	Test accuracy = 9291/10000 = 92.91
# Best Test Accuracy = 93.05
#
# Epoch: 86
# Train Loss = 0.015222409492670595	 	Train Accuracy = 49788/50000 = 99.576
# Test Loss = 0.2802413243658935	 	Test accuracy = 9296/10000 = 92.96
# Best Test Accuracy = 93.05
#
# Epoch: 87
# Train Loss = 0.014174530026562455	 	Train Accuracy = 49808/50000 = 99.616
# Test Loss = 0.27470880030076716	 	Test accuracy = 9294/10000 = 92.94
# Best Test Accuracy = 93.05
#
# Epoch: 88
# Train Loss = 0.012545551828411229	 	Train Accuracy = 49866/50000 = 99.732
# Test Loss = 0.2753466744023033	 	Test accuracy = 9298/10000 = 92.98
# Best Test Accuracy = 93.05
#
# Epoch: 89
# Train Loss = 0.012904023608107053	 	Train Accuracy = 49850/50000 = 99.7
# Test Loss = 0.2758615824240672	 	Test accuracy = 9291/10000 = 92.91
# Best Test Accuracy = 93.05
#
# Epoch: 90
# Train Loss = 0.013257456590871677	 	Train Accuracy = 49837/50000 = 99.674
# Test Loss = 0.27689533444899544	 	Test accuracy = 9297/10000 = 92.97
# Best Test Accuracy = 93.05
#
# Epoch: 91
# Train Loss = 0.012872695042442083	 	Train Accuracy = 49842/50000 = 99.684
# Test Loss = 0.2739919466497023	 	Test accuracy = 9298/10000 = 92.98
# Best Test Accuracy = 93.05
#
# Epoch: 92
# Train Loss = 0.013209240445259797	 	Train Accuracy = 49828/50000 = 99.656
# Test Loss = 0.2738116332624532	 	Test accuracy = 9297/10000 = 92.97
# Best Test Accuracy = 93.05
#
# Epoch: 93
# Train Loss = 0.01175486237761062	 	Train Accuracy = 49872/50000 = 99.744
# Test Loss = 0.27518308294724814	 	Test accuracy = 9294/10000 = 92.94
# Best Test Accuracy = 93.05
#
# Epoch: 94
# Train Loss = 0.011750285854012898	 	Train Accuracy = 49878/50000 = 99.756
# Test Loss = 0.27373415439189236	 	Test accuracy = 9308/10000 = 93.08
# Best Test Accuracy = 93.08
#
# Epoch: 95
# Train Loss = 0.012371319806729645	 	Train Accuracy = 49836/50000 = 99.672
# Test Loss = 0.274262299548976	 	Test accuracy = 9312/10000 = 93.12
# Best Test Accuracy = 93.12
#
# Epoch: 96
# Train Loss = 0.012536280106067124	 	Train Accuracy = 49834/50000 = 99.668
# Test Loss = 0.2744783316797848	 	Test accuracy = 9298/10000 = 92.98
# Best Test Accuracy = 93.12
#
# Epoch: 97
# Train Loss = 0.011938706370573158	 	Train Accuracy = 49855/50000 = 99.71
# Test Loss = 0.2744882295403299	 	Test accuracy = 9305/10000 = 93.05
# Best Test Accuracy = 93.12
#
# Epoch: 98
# Train Loss = 0.012001180051602042	 	Train Accuracy = 49851/50000 = 99.702
# Test Loss = 0.27329397644800474	 	Test accuracy = 9299/10000 = 92.99
# Best Test Accuracy = 93.12
#
# Epoch: 99
# Train Loss = 0.011669144223746665	 	Train Accuracy = 49862/50000 = 99.724
# Test Loss = 0.27311865419526643	 	Test accuracy = 9305/10000 = 93.05
# Best Test Accuracy = 93.12
#
# Epoch: 100
# Train Loss = 0.012007099745409262	 	Train Accuracy = 49861/50000 = 99.722
# Test Loss = 0.27368820392632787	 	Test accuracy = 9300/10000 = 93.0
# Best Test Accuracy = 93.12

# %%
# Plotting Losses and Accuracies for the training process (CASE - 3)

plot_metrics(train_accs, test_accs, train_losses, test_losses, 
             max(range(len(test_accs)), key = test_accs.__getitem__), 
             max(test_accs))

# %% [markdown]
# ### CASE - 4: lr = 0.05, momentum = 0.0005, weight_decay = 5e-4

# %%
# Initializing network and setting optimizer and Learning Rate Decay (CASE - 4)

net = initNetwork()

optimizer = optim.SGD(net.parameters(), lr = 0.05, momentum = 0.0005, 
                      weight_decay = 5e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 
                                                       T_max = EPOCHS)

# %%
# Training the ResNet18 (CASE - 4)

best_acc = 0

train_accs = []
train_losses = []

test_accs = []
test_losses = []

for epoch in range(EPOCHS):
  
  train(epoch)
  acc = test(epoch)

  if acc > best_acc:
      best_acc = acc
      torch.save(net.state_dict(), '/content/models/resnet4.pt')
  
  print("Best Test Accuracy = " + str(best_acc))
  scheduler.step()
# Out:
# Epoch: 1
# Train Loss = 1.5489020981752049	 	Train Accuracy = 21338/50000 = 42.676
# Test Loss = 1.4036755667457097	 	Test accuracy = 5178/10000 = 51.78
# Best Test Accuracy = 51.78
#
# Epoch: 2
# Train Loss = 1.0958510176909855	 	Train Accuracy = 30296/50000 = 60.592
# Test Loss = 1.1542768553842473	 	Test accuracy = 6135/10000 = 61.35
# Best Test Accuracy = 61.35
#
# Epoch: 3
# Train Loss = 0.8836244856914901	 	Train Accuracy = 34232/50000 = 68.464
# Test Loss = 0.8426478557948824	 	Test accuracy = 7128/10000 = 71.28
# Best Test Accuracy = 71.28
#
# Epoch: 4
# Train Loss = 0.7580054021247512	 	Train Accuracy = 36574/50000 = 73.148
# Test Loss = 1.1161629331262806	 	Test accuracy = 6718/10000 = 67.18
# Best Test Accuracy = 71.28
#
# Epoch: 5
# Train Loss = 0.6712470659057198	 	Train Accuracy = 38261/50000 = 76.522
# Test Loss = 0.7567005278188971	 	Test accuracy = 7434/10000 = 74.34
# Best Test Accuracy = 74.34
#
# Epoch: 6
# Train Loss = 0.6187855259079458	 	Train Accuracy = 39173/50000 = 78.346
# Test Loss = 0.8228655178335649	 	Test accuracy = 7287/10000 = 72.87
# Best Test Accuracy = 74.34
#
# Epoch: 7
# Train Loss = 0.5701666491873124	 	Train Accuracy = 40077/50000 = 80.154
# Test Loss = 0.8785793449305281	 	Test accuracy = 7150/10000 = 71.5
# Best Test Accuracy = 74.34
#
# Epoch: 8
# Train Loss = 0.524359606492245	 	Train Accuracy = 40768/50000 = 81.536
# Test Loss = 0.7478761763512334	 	Test accuracy = 7514/10000 = 75.14
# Best Test Accuracy = 75.14
#
# Epoch: 9
# Train Loss = 0.49571360072211534	 	Train Accuracy = 41382/50000 = 82.764
# Test Loss = 0.8206125844883013	 	Test accuracy = 7544/10000 = 75.44
# Best Test Accuracy = 75.44
#
# Epoch: 10
# Train Loss = 0.46556161302129934	 	Train Accuracy = 41831/50000 = 83.662
# Test Loss = 0.5353256411190275	 	Test accuracy = 8225/10000 = 82.25
# Best Test Accuracy = 82.25
#
# Epoch: 11
# Train Loss = 0.44577316013748386	 	Train Accuracy = 42284/50000 = 84.568
# Test Loss = 0.5123398975480961	 	Test accuracy = 8317/10000 = 83.17
# Best Test Accuracy = 83.17
#
# Epoch: 12
# Train Loss = 0.4231452768111168	 	Train Accuracy = 42575/50000 = 85.15
# Test Loss = 0.5985673707497271	 	Test accuracy = 8092/10000 = 80.92
# Best Test Accuracy = 83.17
#
# Epoch: 13
# Train Loss = 0.4027090978515727	 	Train Accuracy = 42911/50000 = 85.822
# Test Loss = 0.47791754218596444	 	Test accuracy = 8401/10000 = 84.01
# Best Test Accuracy = 84.01
#
# Epoch: 14
# Train Loss = 0.3791438490152359	 	Train Accuracy = 43359/50000 = 86.718
# Test Loss = 0.4972213865080966	 	Test accuracy = 8405/10000 = 84.05
# Best Test Accuracy = 84.05
#
# Epoch: 15
# Train Loss = 0.3602860889318959	 	Train Accuracy = 43621/50000 = 87.242
# Test Loss = 0.4635135027803952	 	Test accuracy = 8483/10000 = 84.83
# Best Test Accuracy = 84.83
#
# Epoch: 16
# Train Loss = 0.34821443877104297	 	Train Accuracy = 43965/50000 = 87.93
# Test Loss = 0.5773338981067078	 	Test accuracy = 8168/10000 = 81.68
# Best Test Accuracy = 84.83
#
# Epoch: 17
# Train Loss = 0.3325577465545796	 	Train Accuracy = 44189/50000 = 88.378
# Test Loss = 0.41437826050987725	 	Test accuracy = 8603/10000 = 86.03
# Best Test Accuracy = 86.03
#
# Epoch: 18
# Train Loss = 0.31735420935903974	 	Train Accuracy = 44468/50000 = 88.936
# Test Loss = 0.402394135730176	 	Test accuracy = 8671/10000 = 86.71
# Best Test Accuracy = 86.71
#
# Epoch: 19
# Train Loss = 0.31085685535769936	 	Train Accuracy = 44511/50000 = 89.022
# Test Loss = 0.5122691302359859	 	Test accuracy = 8449/10000 = 84.49
# Best Test Accuracy = 86.71
#
# Epoch: 20
# Train Loss = 0.2988911287101638	 	Train Accuracy = 44743/50000 = 89.486
# Test Loss = 0.4714437334597865	 	Test accuracy = 8499/10000 = 84.99
# Best Test Accuracy = 86.71
#
# Epoch: 21
# Train Loss = 0.28119354708420347	 	Train Accuracy = 45059/50000 = 90.118
# Test Loss = 0.44885467728482015	 	Test accuracy = 8553/10000 = 85.53
# Best Test Accuracy = 86.71
#
# Epoch: 22
# Train Loss = 0.27379612651322505	 	Train Accuracy = 45144/50000 = 90.288
# Test Loss = 0.4355534373582164	 	Test accuracy = 8645/10000 = 86.45
# Best Test Accuracy = 86.71
#
# Epoch: 23
# Train Loss = 0.26549683981920447	 	Train Accuracy = 45280/50000 = 90.56
# Test Loss = 0.46690052276170707	 	Test accuracy = 8530/10000 = 85.3
# Best Test Accuracy = 86.71
#
# Epoch: 24
# Train Loss = 0.25489013415315875	 	Train Accuracy = 45552/50000 = 91.104
# Test Loss = 0.43496349227579334	 	Test accuracy = 8665/10000 = 86.65
# Best Test Accuracy = 86.71
#
# Epoch: 25
# Train Loss = 0.2453874638851951	 	Train Accuracy = 45588/50000 = 91.176
# Test Loss = 0.4113979769658439	 	Test accuracy = 8724/10000 = 87.24
# Best Test Accuracy = 87.24
#
# Epoch: 26
# Train Loss = 0.23506947827842228	 	Train Accuracy = 45904/50000 = 91.808
# Test Loss = 0.37092695866204517	 	Test accuracy = 8850/10000 = 88.5
# Best Test Accuracy = 88.5
#
# Epoch: 27
# Train Loss = 0.22578823183427382	 	Train Accuracy = 46009/50000 = 92.018
# Test Loss = 0.42330229904832717	 	Test accuracy = 8726/10000 = 87.26
# Best Test Accuracy = 88.5
#
# Epoch: 28
# Train Loss = 0.21851437630327156	 	Train Accuracy = 46129/50000 = 92.258
# Test Loss = 0.43159272776374336	 	Test accuracy = 8686/10000 = 86.86
# Best Test Accuracy = 88.5
#
# Epoch: 29
# Train Loss = 0.21462021051617838	 	Train Accuracy = 46193/50000 = 92.386
# Test Loss = 0.3370242441379571	 	Test accuracy = 8928/10000 = 89.28
# Best Test Accuracy = 89.28
#
# Epoch: 30
# Train Loss = 0.20514626629517208	 	Train Accuracy = 46378/50000 = 92.756
# Test Loss = 0.3443881126144264	 	Test accuracy = 8967/10000 = 89.67
# Best Test Accuracy = 89.67
#
# Epoch: 31
# Train Loss = 0.20151473579885404	 	Train Accuracy = 46420/50000 = 92.84
# Test Loss = 0.36226289068596274	 	Test accuracy = 8847/10000 = 88.47
# Best Test Accuracy = 89.67
#
# Epoch: 32
# Train Loss = 0.18814972557527634	 	Train Accuracy = 46698/50000 = 93.396
# Test Loss = 0.3550794120830826	 	Test accuracy = 8909/10000 = 89.09
# Best Test Accuracy = 89.67
#
# Epoch: 33
# Train Loss = 0.18196502564203404	 	Train Accuracy = 46765/50000 = 93.53
# Test Loss = 0.3628336723092236	 	Test accuracy = 8899/10000 = 88.99
# Best Test Accuracy = 89.67
#
# Epoch: 34
# Train Loss = 0.175223243949206	 	Train Accuracy = 46927/50000 = 93.854
# Test Loss = 0.39278409469731246	 	Test accuracy = 8810/10000 = 88.1
# Best Test Accuracy = 89.67
#
# Epoch: 35
# Train Loss = 0.1720037224519131	 	Train Accuracy = 46926/50000 = 93.852
# Test Loss = 0.5000018762259544	 	Test accuracy = 8580/10000 = 85.8
# Best Test Accuracy = 89.67
#
# Epoch: 36
# Train Loss = 0.16640723839668972	 	Train Accuracy = 47031/50000 = 94.062
# Test Loss = 0.3580547184506549	 	Test accuracy = 8914/10000 = 89.14
# Best Test Accuracy = 89.67
#
# Epoch: 37
# Train Loss = 0.1597770342550924	 	Train Accuracy = 47151/50000 = 94.302
# Test Loss = 0.41119881615608556	 	Test accuracy = 8780/10000 = 87.8
# Best Test Accuracy = 89.67
#
# Epoch: 38
# Train Loss = 0.15206466492294046	 	Train Accuracy = 47299/50000 = 94.598
# Test Loss = 0.35036603983821746	 	Test accuracy = 8982/10000 = 89.82
# Best Test Accuracy = 89.82
#
# Epoch: 39
# Train Loss = 0.14827407552572466	 	Train Accuracy = 47375/50000 = 94.75
# Test Loss = 0.3505091153179543	 	Test accuracy = 8946/10000 = 89.46
# Best Test Accuracy = 89.82
#
# Epoch: 40
# Train Loss = 0.1407278201559468	 	Train Accuracy = 47488/50000 = 94.976
# Test Loss = 0.4061075796998	 	Test accuracy = 8889/10000 = 88.89
# Best Test Accuracy = 89.82
#
# Epoch: 41
# Train Loss = 0.13578582769426542	 	Train Accuracy = 47623/50000 = 95.246
# Test Loss = 0.4364593340249001	 	Test accuracy = 8740/10000 = 87.4
# Best Test Accuracy = 89.82
#
# Epoch: 42
# Train Loss = 0.13293152050975035	 	Train Accuracy = 47655/50000 = 95.31
# Test Loss = 0.3452176728014705	 	Test accuracy = 8994/10000 = 89.94
# Best Test Accuracy = 89.94
#
# Epoch: 43
# Train Loss = 0.12046830547625756	 	Train Accuracy = 47904/50000 = 95.808
# Test Loss = 0.3698128765519661	 	Test accuracy = 8965/10000 = 89.65
# Best Test Accuracy = 89.94
#
# Epoch: 44
# Train Loss = 0.11965219236319632	 	Train Accuracy = 47910/50000 = 95.82
# Test Loss = 0.3594128908235816	 	Test accuracy = 8976/10000 = 89.76
# Best Test Accuracy = 89.94
#
# Epoch: 45
# Train Loss = 0.11741157108560547	 	Train Accuracy = 47923/50000 = 95.846
# Test Loss = 0.3658420866048789	 	Test accuracy = 8972/10000 = 89.72
# Best Test Accuracy = 89.94
#
# Epoch: 46
# Train Loss = 0.1125636825152218	 	Train Accuracy = 48047/50000 = 96.094
# Test Loss = 0.40929650053193295	 	Test accuracy = 8856/10000 = 88.56
# Best Test Accuracy = 89.94
#
# Epoch: 47
# Train Loss = 0.11091313066194429	 	Train Accuracy = 48019/50000 = 96.038
# Test Loss = 0.3675663024187088	 	Test accuracy = 8976/10000 = 89.76
# Best Test Accuracy = 89.94
#
# Epoch: 48
# Train Loss = 0.1033110411175529	 	Train Accuracy = 48225/50000 = 96.45
# Test Loss = 0.3292971242077743	 	Test accuracy = 9082/10000 = 90.82
# Best Test Accuracy = 90.82
#
# Epoch: 49
# Train Loss = 0.09977268482870458	 	Train Accuracy = 48292/50000 = 96.584
# Test Loss = 0.33555065831051595	 	Test accuracy = 9048/10000 = 90.48
# Best Test Accuracy = 90.82
#
# Epoch: 50
# Train Loss = 0.09502028330893772	 	Train Accuracy = 48325/50000 = 96.65
# Test Loss = 0.36059365506413615	 	Test accuracy = 8996/10000 = 89.96
# Best Test Accuracy = 90.82
#
# Epoch: 51

# %%
# Plotting Losses and Accuracies for the training process (CASE - 4)

plot_metrics(train_accs, test_accs, train_losses, test_losses, 
             max(range(len(test_accs)), key = test_accs.__getitem__), 
             max(test_accs))

# %% [markdown]
# ## Part - 5: Testing ResNet18

# %% [markdown]
# From the results in Part - 4, it is evident that the ResNet trained in **Case - 1** is performing the best as it has the maximum test accuracy of **93.67%**. Hence, we are going to load that model and compute different performace metrics.

# %%
# Loading model from the system and evaluating on the testing set

net = initNetwork()
net.load_state_dict(torch.load('/content/models/resnet1.pt'))

net.eval()
correct = 0
total = 0

predictions = []
labels = []

with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(testloader):

        inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
        outputs = net(inputs)
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        predictions.extend(predicted.cpu())
        labels.extend(targets.cpu())

accuracy = 100. * correct / total
print("The Best Test Accuracy achieved is: " + str(accuracy))

# %% [markdown]
# Now, we look at other performance metrics such as precision, recall and F-1 score.
#
# **Precision:** is the proportion of true positives among all the positive predictions. It measures how well the model identifies positive samples correctly.
#
# **Recall:** also known as sensitivity or true positive rate, is the proportion of true positives among all the actual positive samples. It measures how well the model captures positive samples.
#
# **F1 score:** is the harmonic mean of precision and recall. It balances both precision and recall and provides a single score to evaluate the model's performance.

# %%
# Printing Classification Report

print(classification_report(labels, predictions, 
                            target_names = testset.classes))

# %% [markdown]
# We got a pretty great weighted **F-1 score** of **0.94.**

# %% [markdown]
# Now, let us find out what classes are being misclassified by the network.

# %%
# Plotting Confusion Matrix

fig = plt.figure(figsize = (9, 9));
ax = fig.add_subplot(1, 1, 1);
cm = confusion_matrix(labels, predictions);
cm = ConfusionMatrixDisplay(cm, display_labels = testset.classes);
cm.plot(values_format = 'd', cmap = 'Blues', ax = ax)
plt.xticks(rotation = 20)

# %% [markdown]
# The above figure suggests that **'cat'** and **'dog'** is being misclassified the most for each other.
